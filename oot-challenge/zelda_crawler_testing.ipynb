# %% [markdown]
# # OOT Crawler Testing
#
# ## Base Crawler
#
# I built a BaseCrawler class that handles most of the functionality needed to build a web crawling spider. Check out `base_crawler.py` to see how it works.
#
# I'll import that here and then overwrite the parsing and crawling functions of the BaseCrawler to make it work for this specific challenge.

# %%
from base_crawler import BasicCrawler
from collections import deque
from bs4 import BeautifulSoup

# %%
class ZeldaCrawler(BasicCrawler):
    def __init__(self, base_url, db_name, coll_name, use_selenium=False):
        BasicCrawler.__init__(self, base_url, db_name, coll_name, use_selenium)
        
    def parse_page_for_profiles(self, page_html):
        profiles = []
        soup = BeautifulSoup(page_html, 'html.parser')
        all_anchor_tags = soup.select('a')
        profile_href = 'profiles'
        for anchor_tag in all_anchor_tags:
            try:
                anchor_tag_url = anchor_tag['href']
                if profile_href in anchor_tag_url:
                    profile_url = base_url + anchor_tag_url
                    profile_name = anchor_tag.text
                    profiles.append((profile_url, profile_name))
            except KeyError:
                continue
        return profiles
    
    def crawl(self, coll_name=None, start_from_base=True,
                    start_page_route=None, start_record_name='start'):
        if coll_name:
            self._connect_to_new_collection(coll_name)
        # scrape and save start page
        self._scrape_and_save_start_page(start_record_name, start_from_base,
                                         start_page_route)
        # parse_start_page_for_links
        start_html = self.load_start_html_from_db()
        profiles = self.parse_page_for_profiles(start_html)
        # use queue to force breadth first search
        profiles_queue = deque(profiles)
        while len(profiles_queue) > 0:
            profile_url, profile_name = profiles_queue.popleft()
            print "Scraping page at {}".format(profile_url)
            print "Scraping profile of user {}".format(profile_name)
            self.scrape_and_save_page(profile_url, profile_name)

# %% [markdown]
# ## Custom Parsing Method
#
# The links on this page are unfortunately a little hard to get. Every single link on the page is stored in an anchor (`<a>`) tag, but without a class to differentiate between profiles, speed run videos, navigation, etc. To get around this, let's collect every `<a>` tag and check to see if it is a profile link. If it is, store the url of that profile page along with the profile's user name to make it easier to search for specific users in the MongoDB later.
#
# ## Custom Crawling Function
#
# Kept most of the same code from the original .crawl() method of the BasicCrawler base class, with the following modifications:
#
# * Used the custom parsing method `parse_page_for_profiles` instead of the `parse_page_for_links` method.
# * Modified the simple status messages to include the user name so I can keep track of what the spider is doing.
# * Made the spider only scrape one level deep.
#   * The BaseCrawler will eventually (it is a work in progress) have the capability of scraping to an arbitrary depth defined by a given stopping criteria, so I overwrote the behavior here since we only want the users on the leaderboard already.
#
#
# ## Testing the ZeldaCrawler
#
# First let's put in the base URL of the site and the page I want to start crawling from. Also, let's put in the db and collection where I'll want to save the scraped html for parsing later.

# %%
base_url = "http://zeldaspeedruns.com"
page_route = "leaderboards/oot/any"
db_name = 'zelda'
coll_name = 'testing'

# %%
spider = ZeldaCrawler(base_url, db_name, coll_name)

# %%
spider.crawl(start_from_base=False, start_page_route=page_route)
# Out:
# Scraping start page...
# Successful request, status code: 200
# Saving start page html...
# Successfully inserted record at id num 58b38b0fa4571b590b824d4b
# Loading html from start page url http://zeldaspeedruns.com/leaderboards/oot/any
# Scraping page at http://zeldaspeedruns.com/profiles/Torje
# Scraping profile of user Torje
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b10a4571b590b824d4c
# Scraping page at http://zeldaspeedruns.com/profiles/skater82297
# Scraping profile of user skater82297
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b10a4571b590b824d4d
# Scraping page at http://zeldaspeedruns.com/profiles/Jodenstone
# Scraping profile of user Jodenstone
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b11a4571b590b824d4e
# Scraping page at http://zeldaspeedruns.com/profiles/bakerawr
# Scraping profile of user bakerawr
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b12a4571b590b824d4f
# Scraping page at http://zeldaspeedruns.com/profiles/Aliensqueakytoy%20
# Scraping profile of user Aliensqueakytoy
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b12a4571b590b824d50
# Scraping page at http://zeldaspeedruns.com/profiles/doktor_m
# Scraping profile of user doktor_m
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b13a4571b590b824d51
# Scraping page at http://zeldaspeedruns.com/profiles/Amateseru
# Scraping profile of user Amateseru
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b13a4571b590b824d52
# Scraping page at http://zeldaspeedruns.com/profiles/ikswozol
# Scraping profile of user ikswozol
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b13a4571b590b824d53
# Scraping page at http://zeldaspeedruns.com/profiles/Chain
# Scraping profile of user Chain
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b14a4571b590b824d54
# Scraping page at http://zeldaspeedruns.com/profiles/Cosmo
# Scraping profile of user Cosmo
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b14a4571b590b824d55
# Scraping page at http://zeldaspeedruns.com/profiles/TheVirusMaster
# Scraping profile of user TheVirusMaster
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b15a4571b590b824d56
# Scraping page at http://zeldaspeedruns.com/profiles/dannyb21892
# Scraping profile of user dannyb21892
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b15a4571b590b824d57
# Scraping page at http://zeldaspeedruns.com/profiles/realtimeattack64
# Scraping profile of user realtimeattack64
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b16a4571b590b824d58
# Scraping page at http://zeldaspeedruns.com/profiles/Zeldoge
# Scraping profile of user Zeldoge
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b16a4571b590b824d59
# Scraping page at http://zeldaspeedruns.com/profiles/Marco
# Scraping profile of user Marco
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b17a4571b590b824d5a
# Scraping page at http://zeldaspeedruns.com/profiles/SmashMac
# Scraping profile of user SmashMac
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b17a4571b590b824d5b
# Scraping page at http://zeldaspeedruns.com/profiles/ClubLuigi
# Scraping profile of user ClubLuigi
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b17a4571b590b824d5c
# Scraping page at http://zeldaspeedruns.com/profiles/darb_meister30
# Scraping profile of user darb_meister30
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b18a4571b590b824d5d
# Scraping page at http://zeldaspeedruns.com/profiles/NicoSpeedsub
# Scraping profile of user NicoSpeedsub
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b19a4571b590b824d5e
# Scraping page at http://zeldaspeedruns.com/profiles/Bonooruu
# Scraping profile of user Bonooruu
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b19a4571b590b824d5f
# Scraping page at http://zeldaspeedruns.com/profiles/kaylabee17
# Scraping profile of user kaylabee17
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b1aa4571b590b824d60
# Scraping page at http://zeldaspeedruns.com/profiles/ZGSpeedruns
# Scraping profile of user ZGSpeedruns
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b1aa4571b590b824d61
# Scraping page at http://zeldaspeedruns.com/profiles/Kuhls
# Scraping profile of user Kuhls
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b1ba4571b590b824d62
# Scraping page at http://zeldaspeedruns.com/profiles/Yann
# Scraping profile of user Yann
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b1ca4571b590b824d63
# Scraping page at http://zeldaspeedruns.com/profiles/JavaScript
# Scraping profile of user JavaScript
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b1ca4571b590b824d64
# Scraping page at http://zeldaspeedruns.com/profiles/Zudu
# Scraping profile of user Zudu
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b1ca4571b590b824d65
# Scraping page at http://zeldaspeedruns.com/profiles/Pydoyks
# Scraping profile of user Pydoyks
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b1da4571b590b824d66
# Scraping page at http://zeldaspeedruns.com/profiles/wo0denfish
# Scraping profile of user wo0denfish
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b1da4571b590b824d67
# Scraping page at http://zeldaspeedruns.com/profiles/theMakaron
# Scraping profile of user theMakaron
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b1da4571b590b824d68
# Scraping page at http://zeldaspeedruns.com/profiles/ZoraDude119
# Scraping profile of user ZoraDude119
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b1ea4571b590b824d69
# Scraping page at http://zeldaspeedruns.com/profiles/Frogburt
# Scraping profile of user Frogburt
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b1ea4571b590b824d6a
# Scraping page at http://zeldaspeedruns.com/profiles/rzezzy1
# Scraping profile of user rzezzy1
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b1ea4571b590b824d6b
# Scraping page at http://zeldaspeedruns.com/profiles/JustinDT
# Scraping profile of user JustinDT
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b1fa4571b590b824d6c
# Scraping page at http://zeldaspeedruns.com/profiles/HonkyMcButterball
# Scraping profile of user HonkyMcButterball
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b1fa4571b590b824d6d
# Scraping page at http://zeldaspeedruns.com/profiles/Pokey
# Scraping profile of user Pokey
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b20a4571b590b824d6e
# Scraping page at http://zeldaspeedruns.com/profiles/Grokken
# Scraping profile of user Grokken
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b20a4571b590b824d6f
# Scraping page at http://zeldaspeedruns.com/profiles/genesis424
# Scraping profile of user genesis424
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b20a4571b590b824d70
# Scraping page at http://zeldaspeedruns.com/profiles/Dromasylvia
# Scraping profile of user Dromasylvia
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b21a4571b590b824d71
# Scraping page at http://zeldaspeedruns.com/profiles/Jelster
# Scraping profile of user Jelster
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b21a4571b590b824d72
# Scraping page at http://zeldaspeedruns.com/profiles/sva
# Scraping profile of user sva
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b22a4571b590b824d73
# Scraping page at http://zeldaspeedruns.com/profiles/Fudgeyaw
# Scraping profile of user Fudgeyaw
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b22a4571b590b824d74
# Scraping page at http://zeldaspeedruns.com/profiles/Nopefius
# Scraping profile of user Nopefius
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b23a4571b590b824d75
# Scraping page at http://zeldaspeedruns.com/profiles/maxx
# Scraping profile of user maxx
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b23a4571b590b824d76
# Scraping page at http://zeldaspeedruns.com/profiles/SnipinG1337
# Scraping profile of user SnipinG1337
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b23a4571b590b824d77
# Scraping page at http://zeldaspeedruns.com/profiles/Ilher
# Scraping profile of user Ilher
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b24a4571b590b824d78
# Scraping page at http://zeldaspeedruns.com/profiles/MichaelRadar
# Scraping profile of user MichaelRadar
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b24a4571b590b824d79
# Scraping page at http://zeldaspeedruns.com/profiles/nathanisbored
# Scraping profile of user nathanisbored
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b25a4571b590b824d7a
# Scraping page at http://zeldaspeedruns.com/profiles/Melrose
# Scraping profile of user Melrose
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b25a4571b590b824d7b
# Scraping page at http://zeldaspeedruns.com/profiles/Fays
# Scraping profile of user Fays
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b25a4571b590b824d7c
# Scraping page at http://zeldaspeedruns.com/profiles/DindonNashor
# Scraping profile of user DindonNashor
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b25a4571b590b824d7d
# Scraping page at http://zeldaspeedruns.com/profiles/MikamiHero
# Scraping profile of user MikamiHero
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b26a4571b590b824d7e
# Scraping page at http://zeldaspeedruns.com/profiles/MGSpeedruns
# Scraping profile of user MGSpeedruns
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b26a4571b590b824d7f
# Scraping page at http://zeldaspeedruns.com/profiles/Dwagon
# Scraping profile of user Dwagon
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b26a4571b590b824d80
# Scraping page at http://zeldaspeedruns.com/profiles/Geragg34
# Scraping profile of user Geragg34
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b27a4571b590b824d81
# Scraping page at http://zeldaspeedruns.com/profiles/HarpoonCannon
# Scraping profile of user HarpoonCannon
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b27a4571b590b824d82
# Scraping page at http://zeldaspeedruns.com/profiles/Brenn52
# Scraping profile of user Brenn52
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b28a4571b590b824d83
# Scraping page at http://zeldaspeedruns.com/profiles/Balatee
# Scraping profile of user Balatee
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b28a4571b590b824d84
# Scraping page at http://zeldaspeedruns.com/profiles/Retro
# Scraping profile of user Retro
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b28a4571b590b824d85
# Scraping page at http://zeldaspeedruns.com/profiles/Gaiste
# Scraping profile of user Gaiste
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b29a4571b590b824d86
# Scraping page at http://zeldaspeedruns.com/profiles/Aklar_45
# Scraping profile of user Aklar_45
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b29a4571b590b824d87
# Scraping page at http://zeldaspeedruns.com/profiles/Letharial
# Scraping profile of user Letharial
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b29a4571b590b824d88
# Scraping page at http://zeldaspeedruns.com/profiles/Mijailinator
# Scraping profile of user Mijailinator
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b2aa4571b590b824d89
# Scraping page at http://zeldaspeedruns.com/profiles/Jbop
# Scraping profile of user Jbop
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b2aa4571b590b824d8a
# Scraping page at http://zeldaspeedruns.com/profiles/Lozoots
# Scraping profile of user Lozoots
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b2aa4571b590b824d8b
# Scraping page at http://zeldaspeedruns.com/profiles/JPSMonStahZInc
# Scraping profile of user JPSMonStahZInc
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b2aa4571b590b824d8c
# Scraping page at http://zeldaspeedruns.com/profiles/Moodehh
# Scraping profile of user Moodehh
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b2ba4571b590b824d8d
# Scraping page at http://zeldaspeedruns.com/profiles/Cma
# Scraping profile of user Cma
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b2ba4571b590b824d8e
# Scraping page at http://zeldaspeedruns.com/profiles/Yodenko
# Scraping profile of user Yodenko
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b2ba4571b590b824d8f
# Scraping page at http://zeldaspeedruns.com/profiles/HapticNoise
# Scraping profile of user HapticNoise
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b2ca4571b590b824d90
# Scraping page at http://zeldaspeedruns.com/profiles/Gregortixlkyns
# Scraping profile of user Gregortixlkyns
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b2da4571b590b824d91
# Scraping page at http://zeldaspeedruns.com/profiles/Rampage29
# Scraping profile of user Rampage29
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b2da4571b590b824d92
# Scraping page at http://zeldaspeedruns.com/profiles/dicedeus
# Scraping profile of user dicedeus
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b2da4571b590b824d93
# Scraping page at http://zeldaspeedruns.com/profiles/Bladaw
# Scraping profile of user Bladaw
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b2da4571b590b824d94
# Scraping page at http://zeldaspeedruns.com/profiles/jackkenney
# Scraping profile of user jackkenney
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b2ea4571b590b824d95
# Scraping page at http://zeldaspeedruns.com/profiles/DeppJay
# Scraping profile of user DeppJay
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b2ea4571b590b824d96
# Scraping page at http://zeldaspeedruns.com/profiles/Ultrastar123
# Scraping profile of user Ultrastar123
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b2ea4571b590b824d97
# Scraping page at http://zeldaspeedruns.com/profiles/fullgrowngaming
# Scraping profile of user fullgrowngaming
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b2fa4571b590b824d98
# Scraping page at http://zeldaspeedruns.com/profiles/SkyKnight34
# Scraping profile of user SkyKnight34
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b2fa4571b590b824d99
# Scraping page at http://zeldaspeedruns.com/profiles/YourBoyTroy
# Scraping profile of user YourBoyTroy
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b2fa4571b590b824d9a
# Scraping page at http://zeldaspeedruns.com/profiles/Sonfloro
# Scraping profile of user Sonfloro
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b30a4571b590b824d9b
# Scraping page at http://zeldaspeedruns.com/profiles/Jethro
# Scraping profile of user Jethro
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b30a4571b590b824d9c
# Scraping page at http://zeldaspeedruns.com/profiles/MikeKatz45
# Scraping profile of user MikeKatz45
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b30a4571b590b824d9d
# Scraping page at http://zeldaspeedruns.com/profiles/Mubbsy
# Scraping profile of user Mubbsy
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b31a4571b590b824d9e
# Scraping page at http://zeldaspeedruns.com/profiles/Miraclefoam
# Scraping profile of user Miraclefoam
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b31a4571b590b824d9f
# Scraping page at http://zeldaspeedruns.com/profiles/iamradiox
# Scraping profile of user iamradiox
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b31a4571b590b824da0
# Scraping page at http://zeldaspeedruns.com/profiles/Lavooos
# Scraping profile of user Lavooos
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b32a4571b590b824da1
# Scraping page at http://zeldaspeedruns.com/profiles/Wallis_Reflect
# Scraping profile of user Wallis_Reflect
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b32a4571b590b824da2
# Scraping page at http://zeldaspeedruns.com/profiles/Fishstickslol
# Scraping profile of user Fishstickslol
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b32a4571b590b824da3
# Scraping page at http://zeldaspeedruns.com/profiles/Kryptek
# Scraping profile of user Kryptek
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b32a4571b590b824da4
# Scraping page at http://zeldaspeedruns.com/profiles/cafde
# Scraping profile of user cafde
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b33a4571b590b824da5
# Scraping page at http://zeldaspeedruns.com/profiles/TKC
# Scraping profile of user TKC
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b33a4571b590b824da6
# Scraping page at http://zeldaspeedruns.com/profiles/ragerunner11
# Scraping profile of user ragerunner11
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b33a4571b590b824da7
# Scraping page at http://zeldaspeedruns.com/profiles/SirkRuns
# Scraping profile of user SirkRuns
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b34a4571b590b824da8
# Scraping page at http://zeldaspeedruns.com/profiles/DeathBasket
# Scraping profile of user DeathBasket
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b34a4571b590b824da9
# Scraping page at http://zeldaspeedruns.com/profiles/Jovis
# Scraping profile of user Jovis
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b35a4571b590b824daa
# Scraping page at http://zeldaspeedruns.com/profiles/Official%20Fern
# Scraping profile of user Official Fern
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b35a4571b590b824dab
# Scraping page at http://zeldaspeedruns.com/profiles/Jimbalicious
# Scraping profile of user Jimbalicious
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b35a4571b590b824dac
# Scraping page at http://zeldaspeedruns.com/profiles/EnNopp112
# Scraping profile of user EnNopp112
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b36a4571b590b824dad
# Scraping page at http://zeldaspeedruns.com/profiles/Jgiga
# Scraping profile of user Jgiga
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b36a4571b590b824dae
# Scraping page at http://zeldaspeedruns.com/profiles/Epicc
# Scraping profile of user Epicc
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b36a4571b590b824daf
# Scraping page at http://zeldaspeedruns.com/profiles/ocarinaoftimespeedrunner
# Scraping profile of user ocarinaoftimespeedrunner
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b37a4571b590b824db0
# Scraping page at http://zeldaspeedruns.com/profiles/Kejsmaster
# Scraping profile of user Kejsmaster
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b37a4571b590b824db1
# Scraping page at http://zeldaspeedruns.com/profiles/garbbb
# Scraping profile of user garbbb
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b37a4571b590b824db2
# Scraping page at http://zeldaspeedruns.com/profiles/Vulvanomics
# Scraping profile of user Vulvanomics
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b38a4571b590b824db3
# Scraping page at http://zeldaspeedruns.com/profiles/Ootmmwwlttp
# Scraping profile of user Ootmmwwlttp
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b38a4571b590b824db4
# Scraping page at http://zeldaspeedruns.com/profiles/ArmorySons
# Scraping profile of user ArmorySons
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b38a4571b590b824db5
# Scraping page at http://zeldaspeedruns.com/profiles/Bluepointed
# Scraping profile of user Bluepointed
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b39a4571b590b824db6
# Scraping page at http://zeldaspeedruns.com/profiles/Dan2point5
# Scraping profile of user Dan2point5
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b39a4571b590b824db7
# Scraping page at http://zeldaspeedruns.com/profiles/Hyboirds
# Scraping profile of user Hyboirds
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b39a4571b590b824db8
# Scraping page at http://zeldaspeedruns.com/profiles/Phantom_Lux
# Scraping profile of user Phantom_Lux
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3aa4571b590b824db9
# Scraping page at http://zeldaspeedruns.com/profiles/Tony0890
# Scraping profile of user Tony0890
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3aa4571b590b824dba
# Scraping page at http://zeldaspeedruns.com/profiles/ed58
# Scraping profile of user ed58
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3aa4571b590b824dbb
# Scraping page at http://zeldaspeedruns.com/profiles/Qweczol
# Scraping profile of user Qweczol
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3ba4571b590b824dbc
# Scraping page at http://zeldaspeedruns.com/profiles/hcore
# Scraping profile of user hcore
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3ba4571b590b824dbd
# Scraping page at http://zeldaspeedruns.com/profiles/Andrewajt62
# Scraping profile of user Andrewajt62
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3ba4571b590b824dbe
# Scraping page at http://zeldaspeedruns.com/profiles/Ryan
# Scraping profile of user Ryan
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3ca4571b590b824dbf
# Scraping page at http://zeldaspeedruns.com/profiles/Sakaali90
# Scraping profile of user Sakaali90
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3ca4571b590b824dc0
# Scraping page at http://zeldaspeedruns.com/profiles/Mafham
# Scraping profile of user Mafham
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3ca4571b590b824dc1
# Scraping page at http://zeldaspeedruns.com/profiles/EverAlert
# Scraping profile of user EverAlert
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3da4571b590b824dc2
# Scraping page at http://zeldaspeedruns.com/profiles/Josiah
# Scraping profile of user Josiah
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3da4571b590b824dc3
# Scraping page at http://zeldaspeedruns.com/profiles/Xanthide
# Scraping profile of user Xanthide
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3da4571b590b824dc4
# Scraping page at http://zeldaspeedruns.com/profiles/lloyd53970
# Scraping profile of user lloyd53970
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3ea4571b590b824dc5
# Scraping page at http://zeldaspeedruns.com/profiles/Pikashockz
# Scraping profile of user Pikashockz
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3ea4571b590b824dc6
# Scraping page at http://zeldaspeedruns.com/profiles/Tylooojl
# Scraping profile of user Tylooojl
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3ea4571b590b824dc7
# Scraping page at http://zeldaspeedruns.com/profiles/Makai
# Scraping profile of user Makai
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3fa4571b590b824dc8
# Scraping page at http://zeldaspeedruns.com/profiles/RWhiteGoose
# Scraping profile of user RWhiteGoose
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3fa4571b590b824dc9
# Scraping page at http://zeldaspeedruns.com/profiles/CarlR818
# Scraping profile of user CarlR818
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3fa4571b590b824dca
# Scraping page at http://zeldaspeedruns.com/profiles/Cooley
# Scraping profile of user Cooley
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b3fa4571b590b824dcb
# Scraping page at http://zeldaspeedruns.com/profiles/ZFG
# Scraping profile of user ZFG
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b40a4571b590b824dcc
# Scraping page at http://zeldaspeedruns.com/profiles/Moltov
# Scraping profile of user Moltov
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b40a4571b590b824dcd
# Scraping page at http://zeldaspeedruns.com/profiles/acecraze
# Scraping profile of user acecraze
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b41a4571b590b824dce
# Scraping page at http://zeldaspeedruns.com/profiles/Gallagugar
# Scraping profile of user Gallagugar
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b41a4571b590b824dcf
# Scraping page at http://zeldaspeedruns.com/profiles/splintp
# Scraping profile of user splintp
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b41a4571b590b824dd0
# Scraping page at http://zeldaspeedruns.com/profiles/edzan
# Scraping profile of user edzan
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b42a4571b590b824dd1
# Scraping page at http://zeldaspeedruns.com/profiles/Mattmasterlink
# Scraping profile of user Mattmasterlink
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b42a4571b590b824dd2
# Scraping page at http://zeldaspeedruns.com/profiles/Tokyoboi
# Scraping profile of user Tokyoboi
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b43a4571b590b824dd3
# Scraping page at http://zeldaspeedruns.com/profiles/Skavenger216
# Scraping profile of user Skavenger216
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b43a4571b590b824dd4
# Scraping page at http://zeldaspeedruns.com/profiles/Choco
# Scraping profile of user Choco
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b43a4571b590b824dd5
# Scraping page at http://zeldaspeedruns.com/profiles/Memorecks
# Scraping profile of user Memorecks
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b44a4571b590b824dd6
# Scraping page at http://zeldaspeedruns.com/profiles/Rubixmagic
# Scraping profile of user Rubixmagic
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b44a4571b590b824dd7
# Scraping page at http://zeldaspeedruns.com/profiles/RushinAssassin
# Scraping profile of user RushinAssassin
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b45a4571b590b824dd8
# Scraping page at http://zeldaspeedruns.com/profiles/austiinn
# Scraping profile of user austiinn
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b45a4571b590b824dd9
# Scraping page at http://zeldaspeedruns.com/profiles/Franqly
# Scraping profile of user Franqly
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b45a4571b590b824dda
# Scraping page at http://zeldaspeedruns.com/profiles/Jinjo7x
# Scraping profile of user Jinjo7x
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b46a4571b590b824ddb
# Scraping page at http://zeldaspeedruns.com/profiles/Entanjir
# Scraping profile of user Entanjir
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b46a4571b590b824ddc
# Scraping page at http://zeldaspeedruns.com/profiles/Taiji_San
# Scraping profile of user Taiji_San
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b46a4571b590b824ddd
# Scraping page at http://zeldaspeedruns.com/profiles/Pestlund
# Scraping profile of user Pestlund
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b46a4571b590b824dde
# Scraping page at http://zeldaspeedruns.com/profiles/Davimikyl
# Scraping profile of user Davimikyl
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b47a4571b590b824ddf
# Scraping page at http://zeldaspeedruns.com/profiles/JPro
# Scraping profile of user JPro
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b47a4571b590b824de0
# Scraping page at http://zeldaspeedruns.com/profiles/mrsinji
# Scraping profile of user mrsinji
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b47a4571b590b824de1
# Scraping page at http://zeldaspeedruns.com/profiles/Nighthawkraven18
# Scraping profile of user Nighthawkraven18
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b48a4571b590b824de2
# Scraping page at http://zeldaspeedruns.com/profiles/Reis
# Scraping profile of user Reis
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b48a4571b590b824de3
# Scraping page at http://zeldaspeedruns.com/profiles/Trepidate
# Scraping profile of user Trepidate
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b48a4571b590b824de4
# Scraping page at http://zeldaspeedruns.com/profiles/Nuggelicious
# Scraping profile of user Nuggelicious
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b49a4571b590b824de5
# Scraping page at http://zeldaspeedruns.com/profiles/Plant
# Scraping profile of user Plant
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b49a4571b590b824de6
# Scraping page at http://zeldaspeedruns.com/profiles/Freechips
# Scraping profile of user Freechips
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b49a4571b590b824de7
# Scraping page at http://zeldaspeedruns.com/profiles/Carljeff
# Scraping profile of user Carljeff
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b4aa4571b590b824de8
# Scraping page at http://zeldaspeedruns.com/profiles/GreenTunic
# Scraping profile of user GreenTunic
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b4aa4571b590b824de9
# Scraping page at http://zeldaspeedruns.com/profiles/Fishaman%20P
# Scraping profile of user Fishaman P
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b4aa4571b590b824dea
# Scraping page at http://zeldaspeedruns.com/profiles/footbigmike
# Scraping profile of user footbigmike
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b4ba4571b590b824deb
# Scraping page at http://zeldaspeedruns.com/profiles/Arthanael
# Scraping profile of user Arthanael
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b4ba4571b590b824dec
# Scraping page at http://zeldaspeedruns.com/profiles/calleman123
# Scraping profile of user calleman123
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b4ba4571b590b824ded
# Scraping page at http://zeldaspeedruns.com/profiles/Chasetopher
# Scraping profile of user Chasetopher
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b4ca4571b590b824dee
# Scraping page at http://zeldaspeedruns.com/profiles/Audacity7
# Scraping profile of user Audacity7
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b4ca4571b590b824def
# Scraping page at http://zeldaspeedruns.com/profiles/Elminster
# Scraping profile of user Elminster
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b4da4571b590b824df0
# Scraping page at http://zeldaspeedruns.com/profiles/IceMochaSausage
# Scraping profile of user IceMochaSausage
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b4da4571b590b824df1
# Scraping page at http://zeldaspeedruns.com/profiles/DarkslayerTV
# Scraping profile of user DarkslayerTV
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b4da4571b590b824df2
# Scraping page at http://zeldaspeedruns.com/profiles/Jackatoa
# Scraping profile of user Jackatoa
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b4ea4571b590b824df3
# Scraping page at http://zeldaspeedruns.com/profiles/DerekDickerson
# Scraping profile of user DerekDickerson
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b4ea4571b590b824df4
# Scraping page at http://zeldaspeedruns.com/profiles/YashichiDSF
# Scraping profile of user YashichiDSF
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b4ea4571b590b824df5
# Scraping page at http://zeldaspeedruns.com/profiles/V4Veritas
# Scraping profile of user V4Veritas
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b4fa4571b590b824df6
# Scraping page at http://zeldaspeedruns.com/profiles/Slapony
# Scraping profile of user Slapony
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b4fa4571b590b824df7
# Scraping page at http://zeldaspeedruns.com/profiles/SirWazZabi
# Scraping profile of user SirWazZabi
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b4fa4571b590b824df8
# Scraping page at http://zeldaspeedruns.com/profiles/Deljam
# Scraping profile of user Deljam
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b50a4571b590b824df9
# Scraping page at http://zeldaspeedruns.com/profiles/elorkeloff
# Scraping profile of user elorkeloff
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b50a4571b590b824dfa
# Scraping page at http://zeldaspeedruns.com/profiles/kosmicd12
# Scraping profile of user kosmicd12
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b50a4571b590b824dfb
# Scraping page at http://zeldaspeedruns.com/profiles/KoRLKiller
# Scraping profile of user KoRLKiller
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b50a4571b590b824dfc
# Scraping page at http://zeldaspeedruns.com/profiles/ChristianF23
# Scraping profile of user ChristianF23
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b51a4571b590b824dfd
# Scraping page at http://zeldaspeedruns.com/profiles/gymnast86
# Scraping profile of user gymnast86
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b51a4571b590b824dfe
# Scraping page at http://zeldaspeedruns.com/profiles/Whatsoup
# Scraping profile of user Whatsoup
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b52a4571b590b824dff
# Scraping page at http://zeldaspeedruns.com/profiles/Deku_Knut
# Scraping profile of user Deku_Knut
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b52a4571b590b824e00
# Scraping page at http://zeldaspeedruns.com/profiles/CozySRs
# Scraping profile of user CozySRs
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b52a4571b590b824e01
# Scraping page at http://zeldaspeedruns.com/profiles/izu
# Scraping profile of user izu
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b52a4571b590b824e02
# Scraping page at http://zeldaspeedruns.com/profiles/Djizz91
# Scraping profile of user Djizz91
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b53a4571b590b824e03
# Scraping page at http://zeldaspeedruns.com/profiles/Senti
# Scraping profile of user Senti
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b53a4571b590b824e04
# Scraping page at http://zeldaspeedruns.com/profiles/DLH112
# Scraping profile of user DLH112
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b53a4571b590b824e05
# Scraping page at http://zeldaspeedruns.com/profiles/systemofadown77
# Scraping profile of user systemofadown77
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b54a4571b590b824e06
# Scraping page at http://zeldaspeedruns.com/profiles/summit1g
# Scraping profile of user summit1g
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b54a4571b590b824e07
# Scraping page at http://zeldaspeedruns.com/profiles/Ace
# Scraping profile of user Ace
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b55a4571b590b824e08
# Scraping page at http://zeldaspeedruns.com/profiles/makko
# Scraping profile of user makko
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b55a4571b590b824e09
# Scraping page at http://zeldaspeedruns.com/profiles/eclpsN
# Scraping profile of user eclpsN
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b55a4571b590b824e0a
# Scraping page at http://zeldaspeedruns.com/profiles/FNC
# Scraping profile of user FNC
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b56a4571b590b824e0b
# Scraping page at http://zeldaspeedruns.com/profiles/TrogWW
# Scraping profile of user TrogWW
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b56a4571b590b824e0c
# Scraping page at http://zeldaspeedruns.com/profiles/Samura1man
# Scraping profile of user Samura1man
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b57a4571b590b824e0d
# Scraping page at http://zeldaspeedruns.com/profiles/Nageoire
# Scraping profile of user Nageoire
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b57a4571b590b824e0e
# Scraping page at http://zeldaspeedruns.com/profiles/Shoe1452
# Scraping profile of user Shoe1452
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b57a4571b590b824e0f
# Scraping page at http://zeldaspeedruns.com/profiles/JMD
# Scraping profile of user JMD
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b58a4571b590b824e10
# Scraping page at http://zeldaspeedruns.com/profiles/offsidepuppet
# Scraping profile of user offsidepuppet
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b58a4571b590b824e11
# Scraping page at http://zeldaspeedruns.com/profiles/Sentinel59
# Scraping profile of user Sentinel59
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b58a4571b590b824e12
# Scraping page at http://zeldaspeedruns.com/profiles/Smzeldamaster
# Scraping profile of user Smzeldamaster
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b58a4571b590b824e13
# Scraping page at http://zeldaspeedruns.com/profiles/giuocob
# Scraping profile of user giuocob
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b59a4571b590b824e14
# Scraping page at http://zeldaspeedruns.com/profiles/Jimmie1717
# Scraping profile of user Jimmie1717
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b59a4571b590b824e15
# Scraping page at http://zeldaspeedruns.com/profiles/Glitchym0n
# Scraping profile of user Glitchym0n
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b59a4571b590b824e16
# Scraping page at http://zeldaspeedruns.com/profiles/Valientlink
# Scraping profile of user Valientlink
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b5aa4571b590b824e17
# Scraping page at http://zeldaspeedruns.com/profiles/Zas
# Scraping profile of user Zas
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b5ba4571b590b824e18
# Scraping page at http://zeldaspeedruns.com/profiles/Dragynbeats
# Scraping profile of user Dragynbeats
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b5ba4571b590b824e19
# Scraping page at http://zeldaspeedruns.com/profiles/Devachu
# Scraping profile of user Devachu
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b5ca4571b590b824e1a
# Scraping page at http://zeldaspeedruns.com/profiles/McNallZ
# Scraping profile of user McNallZ
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b5ca4571b590b824e1b
# Scraping page at http://zeldaspeedruns.com/profiles/Ryaaann
# Scraping profile of user Ryaaann
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b5ca4571b590b824e1c
# Scraping page at http://zeldaspeedruns.com/profiles/gregfbgm
# Scraping profile of user gregfbgm
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b5ca4571b590b824e1d
# Scraping page at http://zeldaspeedruns.com/profiles/Demon9
# Scraping profile of user Demon9
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b5da4571b590b824e1e
# Scraping page at http://zeldaspeedruns.com/profiles/Clareance
# Scraping profile of user Clareance
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b5da4571b590b824e1f
# Scraping page at http://zeldaspeedruns.com/profiles/Hawkeye
# Scraping profile of user Hawkeye
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b5ea4571b590b824e20
# Scraping page at http://zeldaspeedruns.com/profiles/hellfoes
# Scraping profile of user hellfoes
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b5ea4571b590b824e21
# Scraping page at http://zeldaspeedruns.com/profiles/fallenwind
# Scraping profile of user fallenwind
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b5ea4571b590b824e22
# Scraping page at http://zeldaspeedruns.com/profiles/synax444
# Scraping profile of user synax444
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b5fa4571b590b824e23
# Scraping page at http://zeldaspeedruns.com/profiles/TeighMart
# Scraping profile of user TeighMart
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b5fa4571b590b824e24
# Scraping page at http://zeldaspeedruns.com/profiles/Dreux
# Scraping profile of user Dreux
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b5fa4571b590b824e25
# Scraping page at http://zeldaspeedruns.com/profiles/Quinnnnn314
# Scraping profile of user Quinnnnn314
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38b60a4571b590b824e26
# Scraping page at http://zeldaspeedruns.com/profiles/jagen31
# Scraping profile of user jagen31
# Successful request, status code: 200
# Saving page html...
# ...
# Scraping profile of user Erodneequinox
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c16a4571b590b825055
# Scraping page at http://zeldaspeedruns.com/profiles/Windfall
# Scraping profile of user Windfall
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c16a4571b590b825056
# Scraping page at http://zeldaspeedruns.com/profiles/jtttobv
# Scraping profile of user jtttobv
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c16a4571b590b825057
# Scraping page at http://zeldaspeedruns.com/profiles/ReigenHargen
# Scraping profile of user ReigenHargen
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c17a4571b590b825058
# Scraping page at http://zeldaspeedruns.com/profiles/Dr4c0
# Scraping profile of user Dr4c0
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c18a4571b590b825059
# Scraping page at http://zeldaspeedruns.com/profiles/MelonSpeedruns
# Scraping profile of user MelonSpeedruns
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c19a4571b590b82505a
# Scraping page at http://zeldaspeedruns.com/profiles/derstuk
# Scraping profile of user derstuk
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c19a4571b590b82505b
# Scraping page at http://zeldaspeedruns.com/profiles/Aubis2
# Scraping profile of user Aubis2
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c19a4571b590b82505c
# Scraping page at http://zeldaspeedruns.com/profiles/kf94
# Scraping profile of user kf94
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c19a4571b590b82505d
# Scraping page at http://zeldaspeedruns.com/profiles/LinksDarkHalf
# Scraping profile of user LinksDarkHalf
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1aa4571b590b82505e
# Scraping page at http://zeldaspeedruns.com/profiles/bigfoot1919
# Scraping profile of user bigfoot1919
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1aa4571b590b82505f
# Scraping page at http://zeldaspeedruns.com/profiles/Wwassup
# Scraping profile of user Wwassup
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1aa4571b590b825060
# Scraping page at http://zeldaspeedruns.com/profiles/SpeedrunerSWE
# Scraping profile of user SpeedrunerSWE
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1aa4571b590b825061
# Scraping page at http://zeldaspeedruns.com/profiles/PaWNile
# Scraping profile of user PaWNile
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1ba4571b590b825062
# Scraping page at http://zeldaspeedruns.com/profiles/PookGamer
# Scraping profile of user PookGamer
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1ba4571b590b825063
# Scraping page at http://zeldaspeedruns.com/profiles/Rumiko
# Scraping profile of user Rumiko
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1ba4571b590b825064
# Scraping page at http://zeldaspeedruns.com/profiles/TheCreecer
# Scraping profile of user TheCreecer
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1ba4571b590b825065
# Scraping page at http://zeldaspeedruns.com/profiles/Hgames1996
# Scraping profile of user Hgames1996
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1ca4571b590b825066
# Scraping page at http://zeldaspeedruns.com/profiles/speedracer
# Scraping profile of user speedracer
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1ca4571b590b825067
# Scraping page at http://zeldaspeedruns.com/profiles/Frosty
# Scraping profile of user Frosty
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1da4571b590b825068
# Scraping page at http://zeldaspeedruns.com/profiles/KrimtonZ
# Scraping profile of user KrimtonZ
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1da4571b590b825069
# Scraping page at http://zeldaspeedruns.com/profiles/Da3iD
# Scraping profile of user Da3iD
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1da4571b590b82506a
# Scraping page at http://zeldaspeedruns.com/profiles/LukeTheLuigiBro
# Scraping profile of user LukeTheLuigiBro
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1da4571b590b82506b
# Scraping page at http://zeldaspeedruns.com/profiles/grockey3
# Scraping profile of user grockey3
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1ea4571b590b82506c
# Scraping page at http://zeldaspeedruns.com/profiles/Indextic
# Scraping profile of user Indextic
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1ea4571b590b82506d
# Scraping page at http://zeldaspeedruns.com/profiles/Vanckey
# Scraping profile of user Vanckey
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1ea4571b590b82506e
# Scraping page at http://zeldaspeedruns.com/profiles/Smosh3box
# Scraping profile of user Smosh3box
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1ea4571b590b82506f
# Scraping page at http://zeldaspeedruns.com/profiles/CoolFish14
# Scraping profile of user CoolFish14
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1fa4571b590b825070
# Scraping page at http://zeldaspeedruns.com/profiles/Mr_Carter
# Scraping profile of user Mr_Carter
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1fa4571b590b825071
# Scraping page at http://zeldaspeedruns.com/profiles/gham7
# Scraping profile of user gham7
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c1fa4571b590b825072
# Scraping page at http://zeldaspeedruns.com/profiles/SampleName_
# Scraping profile of user SampleName_
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c20a4571b590b825073
# Scraping page at http://zeldaspeedruns.com/profiles/TriFriends
# Scraping profile of user TriFriends
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c20a4571b590b825074
# Scraping page at http://zeldaspeedruns.com/profiles/camisbored
# Scraping profile of user camisbored
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c20a4571b590b825075
# Scraping page at http://zeldaspeedruns.com/profiles/LoZRunner23
# Scraping profile of user LoZRunner23
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c20a4571b590b825076
# Scraping page at http://zeldaspeedruns.com/profiles/ingx24
# Scraping profile of user ingx24
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c21a4571b590b825077
# Scraping page at http://zeldaspeedruns.com/profiles/Bismuth
# Scraping profile of user Bismuth
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c21a4571b590b825078
# Scraping page at http://zeldaspeedruns.com/profiles/aleckermit
# Scraping profile of user aleckermit
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c21a4571b590b825079
# Scraping page at http://zeldaspeedruns.com/profiles/Pheenoh
# Scraping profile of user Pheenoh
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c22a4571b590b82507a
# Scraping page at http://zeldaspeedruns.com/profiles/FrankerZxXx69420Speedruns
# Scraping profile of user FrankerZxXx69420Speedruns
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c22a4571b590b82507b
# Scraping page at http://zeldaspeedruns.com/profiles/Groove%20Heaven
# Scraping profile of user Groove Heaven
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c22a4571b590b82507c
# Scraping page at http://zeldaspeedruns.com/profiles/cloudzack117
# Scraping profile of user cloudzack117
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c23a4571b590b82507d
# Scraping page at http://zeldaspeedruns.com/profiles/A%20Pig%20that%20flys
# Scraping profile of user A Pig that flys
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c23a4571b590b82507e
# Scraping page at http://zeldaspeedruns.com/profiles/Tim%20
# Scraping profile of user Tim
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c23a4571b590b82507f
# Scraping page at http://zeldaspeedruns.com/profiles/Josharooski
# Scraping profile of user Josharooski
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c24a4571b590b825080
# Scraping page at http://zeldaspeedruns.com/profiles/Jenslang
# Scraping profile of user Jenslang
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c24a4571b590b825081
# Scraping page at http://zeldaspeedruns.com/profiles/Gurdill63
# Scraping profile of user Gurdill63
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c25a4571b590b825082
# Scraping page at http://zeldaspeedruns.com/profiles/Flanthis
# Scraping profile of user Flanthis
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c25a4571b590b825083
# Scraping page at http://zeldaspeedruns.com/profiles/TheCowness
# Scraping profile of user TheCowness
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c25a4571b590b825084
# Scraping page at http://zeldaspeedruns.com/profiles/blkyoshi
# Scraping profile of user blkyoshi
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c26a4571b590b825085
# Scraping page at http://zeldaspeedruns.com/profiles/TylersGaming
# Scraping profile of user TylersGaming
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c26a4571b590b825086
# Scraping page at http://zeldaspeedruns.com/profiles/KRob16
# Scraping profile of user KRob16
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c26a4571b590b825087
# Scraping page at http://zeldaspeedruns.com/profiles/OnlyWhenItRains
# Scraping profile of user OnlyWhenItRains
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c27a4571b590b825088
# Scraping page at http://zeldaspeedruns.com/profiles/TLOZ64
# Scraping profile of user TLOZ64
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c27a4571b590b825089
# Scraping page at http://zeldaspeedruns.com/profiles/minionprocyk
# Scraping profile of user minionprocyk
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c27a4571b590b82508a
# Scraping page at http://zeldaspeedruns.com/profiles/EmilianoRdzG
# Scraping profile of user EmilianoRdzG
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c28a4571b590b82508b
# Scraping page at http://zeldaspeedruns.com/profiles/arnfear
# Scraping profile of user arnfear
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c28a4571b590b82508c
# Scraping page at http://zeldaspeedruns.com/profiles/superlink47
# Scraping profile of user superlink47
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c28a4571b590b82508d
# Scraping page at http://zeldaspeedruns.com/profiles/Kaztalek
# Scraping profile of user Kaztalek
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c29a4571b590b82508e
# Scraping page at http://zeldaspeedruns.com/profiles/Kappal
# Scraping profile of user Kappal
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c29a4571b590b82508f
# Scraping page at http://zeldaspeedruns.com/profiles/poopguy117
# Scraping profile of user poopguy117
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c29a4571b590b825090
# Scraping page at http://zeldaspeedruns.com/profiles/spotrunsfast
# Scraping profile of user spotrunsfast
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c29a4571b590b825091
# Scraping page at http://zeldaspeedruns.com/profiles/NathanGaming247
# Scraping profile of user NathanGaming247
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c2aa4571b590b825092
# Scraping page at http://zeldaspeedruns.com/profiles/ZeldaLover
# Scraping profile of user ZeldaLover
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c2aa4571b590b825093
# Scraping page at http://zeldaspeedruns.com/profiles/dekap
# Scraping profile of user dekap
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c2aa4571b590b825094
# Scraping page at http://zeldaspeedruns.com/profiles/Nate%20Culpepper
# Scraping profile of user Nate Culpepper
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c2aa4571b590b825095
# Scraping page at http://zeldaspeedruns.com/profiles/owenthedominator
# Scraping profile of user owenthedominator
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c2ba4571b590b825096
# Scraping page at http://zeldaspeedruns.com/profiles/Zeldadude111
# Scraping profile of user Zeldadude111
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c2ba4571b590b825097
# Scraping page at http://zeldaspeedruns.com/profiles/RRHAN%201JZ
# Scraping profile of user RRHAN 1JZ
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c2ba4571b590b825098
# Scraping page at http://zeldaspeedruns.com/profiles/IngusRogeth
# Scraping profile of user IngusRogeth
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c2ca4571b590b825099
# Scraping page at http://zeldaspeedruns.com/profiles/bielhgabrielh
# Scraping profile of user bielhgabrielh
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c2ca4571b590b82509a
# Scraping page at http://zeldaspeedruns.com/profiles/Boibro
# Scraping profile of user Boibro
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c2ca4571b590b82509b
# Scraping page at http://zeldaspeedruns.com/profiles/for%20academic%20purposes
# Scraping profile of user for academic purposes
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c2da4571b590b82509c
# Scraping page at http://zeldaspeedruns.com/profiles/superguerrer3
# Scraping profile of user superguerrer3
# Successful request, status code: 200
# Saving page html...
# Successfully inserted record at id num 58b38c2da4571b590b82509d

# %% [markdown]
# ## Success! (Maybe...)
#
# Looks like the spider worked, but with so many hits it is too hard to visually check that every request had 200 status code. Let's double check the counts, we should have 1 start page in the db and 850 user profile pages.

# %%
# Counting the start pages
start_page_count = spider.collection.find({'start_page':True}).count()

# %%
# Just like the highlander, there can only be one...
start_page_count
# Out:
# 1

# %%
# Ok, that looks like it worked.
# Now more imporantly, there should be 850 user pages
# Let's count those...
user_pages_count = spider.collection.find({'start_page': False}).count()

# %%
user_pages_count
# Out:
# 850

# %% [markdown]
# ## Success! (Really!)
#
# Looks like the custom ZeldaCrawler is in business. Now that I know it is working, I'll port it over to `zelda_crawler.py` to use later in this scraping challenge.
