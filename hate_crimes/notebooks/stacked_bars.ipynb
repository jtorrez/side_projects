# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from bokeh.charts import Bar
from bokeh.models import Legend
from bokeh.charts.attributes import cat, color
from bokeh.charts.operations import blend
from bokeh.io import output_notebook, show
from bokeh.layouts import gridplot

# %matplotlib inline

# %%
df = pd.read_csv('../data/2014_hate_crimes.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 7 columns):
# bias_ motivation    36 non-null object
# incidents           36 non-null object
# offenses            36 non-null object
# victims             36 non-null object
# known_offenders     36 non-null object
# Unnamed: 5          0 non-null float64
# Unnamed: 6          2 non-null object
# dtypes: float64(1), object(6)
# memory usage: 2.0+ KB

# %%
del df['Unnamed: 5']
del df['Unnamed: 6']

# %%
df.rename(columns={'bias_ motivation': 'bias_motivation' }, inplace=True)

# %%
cols_to_clean = ['incidents', 'offenses', 'victims', 'known_offenders']

for col in cols_to_clean:
    df[col] = df[col].str.replace(',','').astype(int)

# %%
df.set_index('bias_motivation', inplace=True)

# %%
clean_df = df.T

# %%
clean_df.drop('known_offenders', axis=0, inplace=True)

# %%
clean_df.reset_index(inplace=True)

# %%
clean_df.rename(columns={'index': 'crimes' }, inplace=True)

# %%
clean_df
# Out:
# bias_motivation     crimes  Total  Single-Bias Incidents  Race  Anti-White  \
# 0                incidents   5479                   5462  2568         593
# 1                 offenses   6418                   6385  3081         701
# 2                  victims   6727                   6681  3227         734
#
# bias_motivation  Anti-Black or African American  \
# 0                                          1621
# 1                                          1955
# 2                                          2022
#
# bias_motivation  Anti-American Indian or Alaska Native  Anti-Asian  \
# 0                                                  130         140
# 1                                                  142         168
# 2                                                  148         201
#
# bias_motivation  Anti-Native Hawaiian or Other Pacific Islander  \
# 0                                                             3
# 1                                                             4
# 2                                                             4
#
# bias_motivation  Anti-Multiple Races, Group            ...             \
# 0                                        81            ...
# 1                                       111            ...
# 2                                       118            ...
#
# bias_motivation  Disability  Anti-Physical  Anti-Mental  Gender:  Anti-Male  \
# 0                        84             23           61       33         10
# 1                        95             26           69       40         12
# 2                        96             26           70       40         12
#
# bias_motivation  Anti-Female  Gender Identity:  Anti-Transgender  \
# 0                         23                98                58
# 1                         28               109                69
# 2                         28               109                69
#
# bias_motivation  Anti-Gender Non-Conforming  Multiple-Bias Incidents4
# 0                                        40                        17
# 1                                        40                        33
# 2                                        40                        46
#
# [3 rows x 37 columns]

# %%
output_notebook()

bar = Bar(clean_df,
          toolbar_location='above',
          values=blend('Anti-White','Anti-Black or African American',
                       'Anti-American Indian or Alaska Native', 
                       'Anti-Asian','Anti-Native Hawaiian or Other Pacific Islander',
                       'Anti-Multiple Races, Group', 
                       name='bias type', labels_name='bias_type'),
          label=cat(columns='crimes', sort=False),
          stack=cat(columns='bias_type', sort=False),
          color=color(columns='bias_type',sort=False),
          legend=None,
          xlabel='Categories',
          ylabel='Count',
          title="2014 Single Bias Hate Crimes By Count",
          tooltips=[('bias type', '@bias_type'), ('crime', '@crimes')],
          plot_width=600,
          plot_height=600)


show(bar)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2fe0df08-99b9-4bf6-81fb-85b011b7f879">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="4d5ada60-d7ca-4cf4-91c9-b879c3dadc82"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#4d5ada60-d7ca-4cf4-91c9-b879c3dadc82").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4d5ada60-d7ca-4cf4-91c9-b879c3dadc82");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4d5ada60-d7ca-4cf4-91c9-b879c3dadc82' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"91e86b6f-8eae-428b-ae21-88033c76489c":{"roots":{"references":[{"attributes":{"plot":null,"text":"2014 Single Bias Hate Crimes By Count"},"id":"f39d9b27-0d28-4f94-87d9-b4d893bd45ff","type":"Title"},{"attributes":{"data_source":{"id":"bc052613-9b6a-47d1-b680-d7b536701a58","type":"ColumnDataSource"},"glyph":{"id":"8112f49c-bef3-4147-8e79-c755da07f167","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"db18c272-1c6f-4692-9270-a7a94ba53688","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"
anti-White','Anti-Black or African American',
                       'Anti-American Indian or Alaska Native', 
                       'Anti-Asian','Anti-Native Hawaiian or Other Pacific Islander',
                       'Anti-Multiple Races, Group']

# %%
for col in cols:
    perc_df[col] = perc_df[col] / perc_df['Race']

# %%
bar = Bar(perc_df,
          values=blend('Anti-White','Anti-Black or African American',
                       'Anti-American Indian or Alaska Native', 
                       'Anti-Asian','Anti-Native Hawaiian or Other Pacific Islander',
                       'Anti-Multiple Races, Group', 
                       name='bias type', labels_name='bias_type'),
          label=cat(columns='crimes', sort=False),
          stack=cat(columns='bias_type', sort=False),
          color=color(columns='bias_type',sort=False),
          legend=None,
          xlabel='Categories',
          ylabel='Percentage',
          title="2014 Single Bias Hate Crimes By Percentage",
          tooltips=[('bias type', '@bias_type'), ('crime', '@crimes')])


show(bar)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="7f30abdb-d575-4a91-8b59-aad85197e41c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#7f30abdb-d575-4a91-8b59-aad85197e41c").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7f30abdb-d575-4a91-8b59-aad85197e41c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7f30abdb-d575-4a91-8b59-aad85197e41c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"85793e3a-673b-455b-84a8-6fc0afc5df93":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b43a1de9-f1ac-48bb-adba-7f8bf677fbd3","type":"Rect"},{"attributes":{"data_source":{"id":"02b67c21-7fb0-4d3c-81e7-18041fcaed1e","type":"ColumnDataSource"},"glyph":{"id":"0e14c20a-523d-4f20-8cfa-2c77f03e1135","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"fb3d50c7-165b-40fd-bda1-1e8b7511d7a2","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":"2014 Single Bias Hate Crimes By Percentage"},"id":"ead6fece-bf85-4549-bedc-6e48c6c7bcc5","type":"Title"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"bias_type":["Anti-Asian"],"chart_index":[{"bias_type":"Anti-Asian","crimes":"victims"}],"color":["#df5320"],"crimes":["victims"],"fill_alpha":[0.8],"height":[0.06228695382708398],"label":[{"bias_type":"Anti-Asian","crimes":"victims"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["victims"],"y":[0.9310505113108151]}},"id":"cbc167c0-1976-4ac9-9b37-fe8f1addee1b","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"bias_type":["Anti-White"],"chart_index":[{"bias_type":"Anti-White","crimes":"victims"}],"color":["#f22c40"],"crimes":["victims"],"fill_alpha":[0.8],"height":[0.22745584133870467],"label":[{"bias_type":"Anti-White","crimes":"victims"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["victims"],"y":[0.11372792066935233]}},"id":"e574ced7-f57d-43c5-b283-a31341801b8b","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"cbc167c0-1976-4ac9-9b37-fe8f1addee1b","type":"ColumnDataSource"},"glyph":{"id":"2f4fd5ba-f09f-45a7-90c5-8e3b41c5b19a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3f6c0e91-00b1-47cb-9089-60c42ef6ee43","type":"GlyphRenderer"},{"attributes":{},"id":"be93a88e-ab8a-49c5-af36-44de93d4b9d8","type":"CategoricalTickFormatter"},{"attributes":{"plot":{"id":"986339b2-5681-4bbc-8c28-386bd3510fe9","subtype":"Chart","type":"Plot"}},"id":"cee34fcc-5814-47b6-84ed-157f14f3d00d","type":"PanTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3e2f9515-66c0-4ea4-8698-627a6f00a57f","type":"Rect"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"cee34fcc-5814-47b6-84ed-157f14f3d00d","type":"PanTool"},{"id":"d9925916-1d76-49ab-a2de-e6cf8bf0a635","type":"WheelZoomTool"},{"id":"721d802d-8882-4811-8175-ad6f8afc3cea","type":"BoxZoomTool"},{"id":"a9ed3969-4025-421a-b067-ce17121aa5c7","type":"SaveTool"},{"id":"d0188211-131a-4fae-8865-430ae1bf8612","type":"ResetTool"},{"id":"ea9e1686-7eaa-4cae-a6bc-91a677eb769c","type":"HelpTool"},{"id":"3bb985f3-cb99-4ab2-a3ca-047e77d30c4c","type":"HoverTool"}]},"id":"0cc7fb07-3c79-4e28-8270-6a5b6e2a44d8","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"bias_type":["Anti-White"],"chart_index":[{"bias_type":"Anti-White","crimes":"incidents"}],"color":["#f22c40"],"crimes":["incidents"],"fill_alpha":[0.8],"height":[0.2309190031152648],"label":[{"bias_type":"Anti-White","crimes":"incidents"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["incidents"],"y":[0.1154595015576324]}},"id":"ac2fc524-1079-48c1-a89d-7bf8a60103cb","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"ac9ad703-bd97-428b-b7e ...
