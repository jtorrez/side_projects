# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from bokeh.charts import Bar
from bokeh.models import Legend
from bokeh.charts.attributes import cat, color
from bokeh.charts.operations import blend
from bokeh.io import output_notebook, show
from bokeh.layouts import gridplot

# %matplotlib inline

# %%
df = pd.read_csv('../data/2014_hate_crimes.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 7 columns):
# bias_ motivation    36 non-null object
# incidents           36 non-null object
# offenses            36 non-null object
# victims             36 non-null object
# known_offenders     36 non-null object
# Unnamed: 5          0 non-null float64
# Unnamed: 6          2 non-null object
# dtypes: float64(1), object(6)
# memory usage: 2.0+ KB

# %%
del df['Unnamed: 5']
del df['Unnamed: 6']

# %%
df.rename(columns={'bias_ motivation': 'bias_motivation' }, inplace=True)

# %%
cols_to_clean = ['incidents', 'offenses', 'victims', 'known_offenders']

for col in cols_to_clean:
    df[col] = df[col].str.replace(',','').astype(int)

# %%
df.set_index('bias_motivation', inplace=True)

# %%
clean_df = df.T

# %%
clean_df.drop('known_offenders', axis=0, inplace=True)

# %%
clean_df.reset_index(inplace=True)

# %%
clean_df.rename(columns={'index': 'crimes' }, inplace=True)

# %%
clean_df
# Out:
# bias_motivation     crimes  Total  Single-Bias Incidents  Race  Anti-White  \
# 0                incidents   5479                   5462  2568         593
# 1                 offenses   6418                   6385  3081         701
# 2                  victims   6727                   6681  3227         734
#
# bias_motivation  Anti-Black or African American  \
# 0                                          1621
# 1                                          1955
# 2                                          2022
#
# bias_motivation  Anti-American Indian or Alaska Native  Anti-Asian  \
# 0                                                  130         140
# 1                                                  142         168
# 2                                                  148         201
#
# bias_motivation  Anti-Native Hawaiian or Other Pacific Islander  \
# 0                                                             3
# 1                                                             4
# 2                                                             4
#
# bias_motivation  Anti-Multiple Races, Group            ...             \
# 0                                        81            ...
# 1                                       111            ...
# 2                                       118            ...
#
# bias_motivation  Disability  Anti-Physical  Anti-Mental  Gender:  Anti-Male  \
# 0                        84             23           61       33         10
# 1                        95             26           69       40         12
# 2                        96             26           70       40         12
#
# bias_motivation  Anti-Female  Gender Identity:  Anti-Transgender  \
# 0                         23                98                58
# 1                         28               109                69
# 2                         28               109                69
#
# bias_motivation  Anti-Gender Non-Conforming  Multiple-Bias Incidents4
# 0                                        40                        17
# 1                                        40                        33
# 2                                        40                        46
#
# [3 rows x 37 columns]

# %%
output_notebook()

bar = Bar(clean_df,
          toolbar_location='above',
          values=blend('Anti-White','Anti-Black or African American',
                       'Anti-American Indian or Alaska Native', 
                       'Anti-Asian','Anti-Native Hawaiian or Other Pacific Islander',
                       'Anti-Multiple Races, Group', 
                       name='bias type', labels_name='bias_type'),
          label=cat(columns='crimes', sort=False),
          stack=cat(columns='bias_type', sort=False),
          color=color(columns='bias_type',sort=False),
          legend=None,
          xlabel='Categories',
          ylabel='Count',
          title="2014 Single Bias Hate Crimes By Count",
          tooltips=[('bias type', '@bias_type'), ('crime', '@crimes')],
          plot_width=600,
          plot_height=600)


show(bar)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="64506cb9-b961-484b-b6a8-4e437018899b">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="39fd3c07-ef73-43b2-82b4-dfed3232da37"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#39fd3c07-ef73-43b2-82b4-dfed3232da37").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("39fd3c07-ef73-43b2-82b4-dfed3232da37");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '39fd3c07-ef73-43b2-82b4-dfed3232da37' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"0bdb3c45-e5b9-4b24-ade9-814e570623b0":{"roots":{"references":[{"attributes":{"callback":null,"end":3388.35},"id":"d2a5fce9-f8b5-4da5-aeb2-608ab0d452b6","type":"Range1d"},{"attributes":{"data_source":{"id":"0dc2a2e0-28c1-4c42-a21f-efc9eca62ca6","type":"ColumnDataSource"},"glyph":{"id":"4cd76ecc-ece5-47f4-9a38-0700fb5e6f0a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"
anti-White','Anti-Black or African American',
                       'Anti-American Indian or Alaska Native', 
                       'Anti-Asian','Anti-Native Hawaiian or Other Pacific Islander',
                       'Anti-Multiple Races, Group']

# %%
for col in cols:
    perc_df[col] = perc_df[col] / perc_df['Race']

# %%
bar = Bar(perc_df,
          values=blend('Anti-White','Anti-Black or African American',
                       'Anti-American Indian or Alaska Native', 
                       'Anti-Asian','Anti-Native Hawaiian or Other Pacific Islander',
                       'Anti-Multiple Races, Group', 
                       name='bias type', labels_name='bias_type'),
          label=cat(columns='crimes', sort=False),
          stack=cat(columns='bias_type', sort=False),
          color=color(columns='bias_type',sort=False),
          legend=None,
          xlabel='Categories',
          ylabel='Count',
          title="2014 Single Bias Hate Crimes By Percentage",
          tooltips=[('bias type', '@bias_type'), ('crime', '@crimes')])


show(bar)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="a46e7a32-0972-476c-89c0-649aa91806ac"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#a46e7a32-0972-476c-89c0-649aa91806ac").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a46e7a32-0972-476c-89c0-649aa91806ac");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a46e7a32-0972-476c-89c0-649aa91806ac' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5607cd00-5fbf-48e3-93d5-894dddcbde2e":{"roots":{"references":[{"attributes":{"data_source":{"id":"48eb42a8-acf0-4f9b-a7fc-9f426a8308be","type":"ColumnDataSource"},"glyph":{"id":"67254d95-e505-48eb-8c1e-f292c13a71a1","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6186cc91-3d86-4c36-acba-3eefdafe203a","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"bias_type":["Anti-White"],"chart_index":[{"bias_type":"Anti-White","crimes":"victims"}],"color":["#f22c40"],"crimes":["victims"],"fill_alpha":[0.8],"height":[0.22745584133870467],"label":[{"bias_type":"Anti-White","crimes":"victims"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["victims"],"y":[0.11372792066935233]}},"id":"00c93c21-7fd6-4ab0-aacf-acbbf6835af1","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"bias_type":["Anti-Native Hawaiian or Other Pacific Islander"],"chart_index":[{"bias_type":"Anti-Native Hawaiian or Other Pacific Islander","crimes":"victims"}],"color":["#00ad9c"],"crimes":["victims"],"fill_alpha":[0.8],"height":[0.0012395413696932136],"label":[{"bias_type":"Anti-Native Hawaiian or Other Pacific Islander","crimes":"victims"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["victims"],"y":[0.9628137589092036]}},"id":"9887c542-7183-4dc9-8465-4d26d12943a7","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"69f06712-b9b8-4332-8c7b-f33827800515","type":"ColumnDataSource"},"glyph":{"id":"df14e7ce-b027-429a-95bd-0ec0219f9b8f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"be50ec2a-f3a1-4aea-81ba-9f78094d90bc","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a437014f-68dc-45fb-ae31-1ed2fcd464bb","type":"Rect"},{"attributes":{"data_source":{"id":"5eb74cb1-fbab-40c2-a8b5-771c4f759384","type":"ColumnDataSource"},"glyph":{"id":"a5445244-9c6b-4070-b907-d619d27be295","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"89dd8331-df26-4fb5-b9e9-a8cf4e9e611d","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"bias_type":["Anti-Native Hawaiian or Other Pacific Islander"],"chart_index":[{"bias_type":"Anti-Native Hawaiian or Other Pacific Islander","crimes":"incidents"}],"color":["#00ad9c"],"crimes":["incidents"],"fill_alpha":[0.8],"height":[0.0011682242990654205],"label":[{"bias_type":"Anti-Native Hawaiian or Other Pacific Islander","crimes":"incidents"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["incidents"],"y":[0.9678738317757009]}},"id":"44cf2808-9586-4908-97a7-7a7ab2434aa8","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"bias_type":["Anti-Multiple Races, Group"],"chart_index":[{"bias_type":"Anti-Multiple Races, Group","crimes":"incidents"}],"color":["#c33ff3"],"crimes":["incidents"],"fill_alpha":[0.8],"height":[0.03154205607476635],"label":[{"bias_type":"Anti-Multiple Races, Group","crimes":"incidents"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["incidents"],"y":[0.9842289719626167]}},"id":"6e3109e0-06e3-4ea5-ba87-f302537cbb38","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"bias_type":["Anti-Multiple Races, Group"],"chart_index":[{"bias_type":"Anti-Multiple Races, Group","cr ...
